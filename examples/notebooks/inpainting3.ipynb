# %%
import matplotlib.pyplot as plt
import numpy as np

def formatImage(image):
    image = image.copy()
    image = image.astype(numpy.float32, copy=False)
    image = image/np.max(image)
    if image.ndim == 2:
        image = image.reshape((image.shape[0], image.shape[1], 1))
    
    return image

def showImage(image):
    tmp = np.squeeze(image)
    if tmp.ndim == 2:
        plt.imshow(tmp,cmap=plt.cm.gray)
    else:
        plt.imshow(image)

# %%
from PIL import Image, ImageDraw
import itertools

def drawRandLine(draw,width,m,n):
    x = [np.random.randint(0,m) for i in range(2)]
    y = [np.random.randint(0,n) for i in range(2)]
    xy = zip(x,y)
    #fill gives the color
    draw.line(xy,fill=255,width=width)
    

def drawLines(image, num_lines, width):
    ''' Return damaged image, along with list of damaged pixels
        should work for greyscle (m,n,1) or rbg images (m,n,3).
        also returns dictionary mapping pixel location to variable index
    '''
    imshape = (image.shape[0], image.shape[1])
    dmg = Image.new("L",imshape)
    draw = ImageDraw.Draw(dmg)
    for i in range(num_lines):
        drawRandLine(draw,width,imshape[0], imshape[1])
    del draw

    idx2pixel = np.array(np.nonzero(np.array(dmg).T)).T
    dmg_image = image.copy()
    dmg_image[idx2pixel[:,0],idx2pixel[:,1],:] = 1.0
    pixel2idx = dict(itertools.izip(itertools.imap(tuple, idx2pixel), xrange(len(idx2pixel))))
    
    return dmg_image, idx2pixel, pixel2idx


def drawText(image, fontsize, length):
    from PIL import Image, ImageDraw, ImageFont
    import textwrap, itertools
    
    imshape = (image.shape[0], image.shape[1])
    dmg = Image.new("L",imshape)
    draw = ImageDraw.Draw(dmg)

    #fontsize = 80
    font = ImageFont.truetype("/Library/Fonts/Georgia.ttf", fontsize)
    text = "Lorem ipsum dolor sit amet, consectetuer adipiscing elit, sed diam nonummy nibh euismod tincidunt ut laoreet dolore magna aliquam erat volutpat. Ut wisi enim ad minim veniam, quis nostrud exerci tation ullamcorper suscipit lobortis nisl ut aliquip ex ea commodo consequat. Duis autem vel eum iriure dolor in hendrerit in vulputate velit esse molestie consequat, vel illum dolore eu feugiat nulla facilisis at vero eros et accumsan et iusto odio dignissim qui blandit praesent luptatum zzril delenit augue duis dolore te feugait nulla facilisi. Nam liber tempor cum soluta nobis eleifend option congue nihil imperdiet doming id quod mazim placerat facer possim assum. Typi non habent claritatem insitam; est usus legentis in iis qui facit eorum claritatem. Investigationes demonstraverunt lectores legere me lius quod ii legunt saepius. Claritas est etiam processus dynamicus, qui sequitur mutationem consuetudium lectorum. Mirum est notare quam littera gothica, quam nunc putamus parum claram, anteposuerit litterarum formas humanitatis per seacula quarta decima et quinta decima. Eodem modo typi, qui nunc nobis videntur parum clari, fiant sollemnes in futurum."
    text = text[0:length]
    lines = textwrap.wrap(text, width = 40)
    w, h = dmg.size
    y_text = 200
    for line in lines:
        width, height = font.getsize(line)
        draw.text((0, y_text), line, font = font, fill = 255)
        y_text += height
        
        
    idx2pixel = np.array(np.nonzero(np.array(dmg).T)).T
    dmg_image = image.copy()
    dmg_image[idx2pixel[:,0],idx2pixel[:,1],:] = 1.0
    pixel2idx = dict(itertools.izip(itertools.imap(tuple, idx2pixel), xrange(len(idx2pixel))))
    
    return dmg_image, idx2pixel, pixel2idx

# %%
import scipy.sparse as sp
from cvxopt import spmatrix

def involvedpairs(pairs):
    ''' Get all the pixel pairs whose gradient involves an unknown pixel.
        Input should be a set or dictionary of pixel pair tuples
    '''
    for pair in pairs: #loop through unknown pixels
        yield pair 
        
        left = (pair[0],pair[1]-1)
        if left[1] >= 0 and left not in pairs: #if 'left' in picture, and not already unknown
            yield left
        
        top = (pair[0]-1,pair[1])
        topright = (pair[0]-1,pair[1]+1)
        #if not on top boundary, top is fixed, and top not already touched by upper right pixel
        if pair[0] > 0 and top not in pairs and topright not in pairs:
            yield top

def formCOO(pair2idx, img):
    m, n, dim = img.shape  
    Is, Js, Vs, bs = [[],[]], [[],[]], [[],[]], [[],[]]
    row = 0
    
    for pixel1 in involvedpairs(pair2idx):
        bottom = (pixel1[0]+1,pixel1[1])
        right= (pixel1[0],pixel1[1]+1)
        
        for i, pixel2 in enumerate([bottom, right]):   
            
            if pixel2[0] >= m or pixel2[1] >= n:
                bs[i].append(np.zeros(dim))
                continue
            
            b = np.zeros(dim)
            for j, pix in enumerate([pixel2, pixel1]):
                if pix in pair2idx: #unknown pixel
                    Is[i].append(row)
                    Js[i].append(pair2idx[pix])
                    Vs[i].append(pow(-1,j))
                else: #known pixel
                    b += pow(-1,j)*img[pix[0],pix[1],:]
            bs[i].append(b)
            
        row += 1
    
    '''
        Form Gx and Gy such that the x-component of the gradient is Gx*x + bx,
        where x is an array representing the unknown pixel values.
    '''
    m = len(bs[0])
    n = len(pair2idx)
    
    #Gx = sp.coo_matrix((Vs[1],(Is[1],Js[1])),shape=(m,n),dtype=np.double)
    #Gy = sp.coo_matrix((Vs[0],(Is[0],Js[0])),shape=(m,n),dtype=np.double)
    Gx = spmatrix(Vs[1], Is[1], Js[1],(m,n))
    Gy = spmatrix(Vs[0], Is[0], Js[0],(m,n))

    bx = np.array(bs[1])
    by = np.array(bs[0])
    
    return Gx, Gy, bx, by

# %%
import cvxpy as cp

def repairImage(dmg_image, idx2pixel, pixel2idx):
    Gx, Gy, bx, by = formCOO(pixel2idx, dmg_image)
    #m, n = Gx.shape
    m, n = Gx.size
    
    print "Gx has size %d by %d"%(m,n)
    x = cp.Variable(n,bx.shape[1])
    #z = cp.Variable(m,2*bx.shape[1])
    
    z = cp.hstack(x.__rmul__(Gx) + bx, x.__rmul__(Gy) + by)
    #constraints = [z[:,0:bx.shape[1]] == Gx*x + bx,
    #z[:,bx.shape[1]:2*bx.shape[1]] ==  Gy*x + by]
    
    objective = cp.Minimize(sum([cp.norm(z[i,:]) for i in range(m)]))
    p = cp.Problem(objective)
    
    result = p.solve(solver=cp.ECOS, verbose=True)
    x = np.array(x.value)
    
    fix_image = dmg_image.copy()
    fix_image[idx2pixel[:,0],idx2pixel[:,1],:] = x
    
    return fix_image

# %% [markdown]
# # Examples
# ## Load an image

# %%
import matplotlib.cbook as cbook
image_file = cbook.get_sample_data('lena.png')
# images available
#logo2.png
#grace_hopper.png
#lena.png
#Minduka_Present_Blue_Pack.png
image = plt.imread(image_file)
image = formatImage(image)
showImage(image)

# %%
from scipy import misc
image = misc.lena()
image = formatImage(image)
showImage(image)

# %% [markdown]
# ## make some 'damage' of lines or text

# %%
dmg_image, idx2pixel, pixel2idx = drawLines(image,3,5)
showImage(dmg_image)

# %%
dmg_image, idx2pixel, pixel2idx = drawText(image, 40, 100)
showImage(dmg_image)

# %% [markdown]
# ## repair the image

# %%
# %%time
fix_image = repairImage(dmg_image, idx2pixel, pixel2idx)
showImage(fix_image)
# Out:
# Gx has size 6456 by 5427
#
# ECOS 1.0.3 - (c) A. Domahidi, Automatic Control Laboratory, ETH Zurich, 2012-2014.
# It     pcost         dcost      gap     pres    dres     k/t     mu      step     IR
#  0   +0.000e+00   -0.000e+00   +1e+04   1e+02   1e-02   1e+00   2e+00    N/A     1 1 -
#  1   +2.195e+01   +2.196e+01   +2e+03   2e+01   2e-03   2e-01   3e-01   0.8571   1 1 1
#  2   +1.022e+02   +1.022e+02   +5e+02   6e+00   4e-04   5e-02   7e-02   0.7636   1 1 1
#  3   +1.635e+02   +1.635e+02   +2e+02   2e+00   2e-04   2e-02   3e-02   0.6960   1 1 1
#  4   +1.917e+02   +1.917e+02   +7e+01   8e-01   7e-05   9e-03   1e-02   0.7261   2 1 1
#  5   +2.053e+02   +2.053e+02   +3e+01   3e-01   2e-05   4e-03   4e-03   0.8827   2 1 2
#  6   +2.110e+02   +2.110e+02   +7e+00   9e-02   7e-06   1e-03   1e-03   0.7622   2 2 2
#  7   +2.128e+02   +2.128e+02   +2e+00   3e-02   2e-06   4e-04   4e-04   0.7530   2 2 2
#  8   +2.135e+02   +2.135e+02   +6e-01   7e-03   6e-07   9e-05   9e-05   0.8678   2 2 2
#  9   +2.137e+02   +2.137e+02   +2e-01   2e-03   2e-07   3e-05   3e-05   0.8982   2 2 2
# 10   +2.137e+02   +2.137e+02   +4e-02   5e-04   4e-08   6e-06   7e-06   0.8330   3 2 2
# 11   +2.137e+02   +2.137e+02   +2e-02   2e-04   2e-08   3e-06   3e-06   0.7172   3 2 2
# 12   +2.137e+02   +2.137e+02   +5e-03   6e-05   5e-09   8e-07   8e-07   0.8651   2 2 2
# 13   +2.137e+02   +2.137e+02   +3e-03   3e-05   2e-09   4e-07   4e-07   0.6356   3 3 3
# 14   +2.137e+02   +2.137e+02   +1e-03   2e-05   1e-09   2e-07   2e-07   0.8502   3 3 3
# 15   +2.137e+02   +2.137e+02   +4e-04   5e-06   4e-10   6e-08   6e-08   0.9569   3 3 3
# 16   +2.137e+02   +2.137e+02   +1e-04   1e-06   1e-10   2e-08   2e-08   0.7745   3 3 3
# 17   +2.137e+02   +2.137e+02   +2e-05   3e-07   2e-11   3e-09   3e-09   0.9574   2 3 3
# 18   +2.137e+02   +2.137e+02   +6e-06   7e-08   6e-12   9e-10   9e-10   0.8305   2 2 2
#
# OPTIMAL (within feastol=7.3e-08, reltol=2.8e-08, abstol=6.0e-06).
# Runtime: 2.628654 seconds.
#
# CPU times: user 17.7 s, sys: 2.46 s, total: 20.1 s
# Wall time: 20.2 s

# %% [markdown]
# # Debugging

# %%
# %%time
Gx, Gy, bx, by = formCOO(pixel2idx, dmg_image)
# Out:
# CPU times: user 523 ms, sys: 14.2 ms, total: 537 ms
# Wall time: 533 ms

# %%
# %%time
#m, n = Gx.shape
m, n = Gx.size
    
print "Gx has size %d by %d"%(m,n)
x = cp.Variable(n,bx.shape[1])
#z = cp.Variable(m,2*bx.shape[1])
tmp = Gx*x
    
#z = cp.hstack(x.__rmul__(Gx) + bx, x.__rmul__(Gy) + by)
#constraints = [z[:,0:bx.shape[1]] == Gx*x + bx,
#z[:,bx.shape[1]:2*bx.shape[1]] ==  Gy*x + by]
    
#
# Out:
# Gx has size 16204 by 12490
# CPU times: user 8.82 s, sys: 7.82 s, total: 16.6 s
# Wall time: 16.9 s

# %%
tmp.args[0]
# Out:
#   (9261, 0)	-1.0
#   (9262, 0)	1.0
#   (8688, 1)	-1.0
#   (9261, 1)	1.0
#   (8108, 2)	-1.0
#   (8688, 2)	1.0
#   (7565, 3)	-1.0
#   (8108, 3)	1.0
#   (4749, 4)	-1.0
#   (7565, 4)	1.0
#   (4154, 5)	-1.0
#   (4749, 5)	1.0
#   (3621, 6)	-1.0
#   (4154, 6)	1.0
#   (6181, 7)	-1.0
#   (6182, 7)	1.0
#   (5611, 8)	-1.0
#   (6181, 8)	1.0
#   (5017, 9)	-1.0
#   (5611, 9)	1.0
#   (2271, 10)	-1.0
#   (5017, 10)	1.0
#   (1695, 11)	-1.0
#   (2271, 11)	1.0
#   (1103, 12)	-1.0
#   :	:
#   (5769, 12477)	1.0
#   (5177, 12478)	1.0
#   (6958, 12478)	-1.0
#   (6352, 12479)	-1.0
#   (6958, 12479)	1.0
#   (6352, 12480)	1.0
#   (12734, 12480)	-1.0
#   (12129, 12481)	-1.0
#   (12734, 12481)	1.0
#   (12129, 12482)	1.0
#   (13893, 12482)	-1.0
#   (13893, 12483)	1.0
#   (15432, 12483)	-1.0
#   (10391, 12484)	-1.0
#   (15432, 12484)	1.0
#   (9826, 12485)	-1.0
#   (10391, 12485)	1.0
#   (9826, 12486)	1.0
#   (11547, 12486)	-1.0
#   (10965, 12487)	-1.0
#   (11547, 12487)	1.0
#   (10965, 12488)	1.0
#   (14974, 12488)	-1.0
#   (14336, 12489)	-1.0
#   (14974, 12489)	1.0

# %%
# %%time
#(Gx*x)._dcp_attr

objective = cp.Minimize(sum([cp.norm(z[i,:]) for i in range(m)]))
p = cp.Problem(objective,constraints)
result = p.solve(solver=cp.ECOS, verbose=True)
x = np.array(x.value)
    
fix_image = dmg_image.copy()
fix_image[idx2pixel[:,0],idx2pixel[:,1],:] = x
# Out:
# ECOS 1.0.3 - (c) A. Domahidi, Automatic Control Laboratory, ETH Zurich, 2012-2014.
#
# It     pcost         dcost      gap     pres    dres     k/t     mu      step     IR
#  0   +0.000e+00   -0.000e+00   +3e+04   2e+02   1e-02   1e+00   2e+00    N/A     1 1 -
#  1   +5.764e+01   +5.766e+01   +4e+03   3e+01   2e-03   2e-01   3e-01   0.8542   1 1 1
#  2   +2.556e+02   +2.556e+02   +1e+03   9e+00   4e-04   5e-02   7e-02   0.7723   1 1 1
#  3   +4.063e+02   +4.063e+02   +4e+02   3e+00   1e-04   2e-02   2e-02   0.6984   1 1 1
#  4   +4.785e+02   +4.785e+02   +2e+02   1e+00   6e-05   8e-03   9e-03   0.7187   2 1 2
#  5   +5.125e+02   +5.125e+02   +5e+01   4e-01   2e-05   3e-03   3e-03   0.8166   2 2 2
#  6   +5.246e+02   +5.246e+02   +2e+01   1e-01   7e-06   1e-03   1e-03   0.7694   2 2 2
#  7   +5.296e+02   +5.296e+02   +4e+00   3e-02   2e-06   2e-04   3e-04   0.8826   2 2 2
#  8   +5.306e+02   +5.306e+02   +2e+00   1e-02   6e-07   9e-05   1e-04   0.7645   2 2 2
#  9   +5.310e+02   +5.310e+02   +8e-01   6e-03   3e-07   5e-05   5e-05   0.7451   2 2 2
# 10   +5.312e+02   +5.312e+02   +2e-01   2e-03   9e-08   1e-05   1e-05   0.9666   2 2 2
# 11   +5.313e+02   +5.313e+02   +3e-02   3e-04   1e-08   2e-06   2e-06   0.9378   3 2 2
# 12   +5.313e+02   +5.313e+02   +1e-02   1e-04   5e-09   7e-07   8e-07   0.9052   3 3 3
# 13   +5.313e+02   +5.313e+02   +5e-03   4e-05   2e-09   3e-07   3e-07   0.7786   3 3 3
# 14   +5.313e+02   +5.313e+02   +7e-04   6e-06   3e-10   4e-08   4e-08   0.9899   3 3 3
# 15   +5.313e+02   +5.313e+02   +2e-04   1e-06   7e-11   1e-08   1e-08   0.8475   3 3 3
# 16   +5.313e+02   +5.313e+02   +9e-05   7e-07   3e-11   5e-09   5e-09   0.7335   2 3 3
# 17   +5.313e+02   +5.313e+02   +3e-05   2e-07   1e-11   2e-09   2e-09   0.9302   2 3 3
# OPTIMAL (within feastol=2.0e-07, reltol=4.9e-08, abstol=2.6e-05).
# Runtime: 6.944049 seconds.
#
# CPU times: user 1min 53s, sys: 931 ms, total: 1min 54s
# Wall time: 1min 55s

# %%
showImage(fix_image)

# %%
del x
del z
del objective
del constraints
del p

# %%
Gx
# Out:
# <6622x5587 sparse matrix, tc='d', nnz=11174>

# %%
from cvxopt import spmatrix
import cvxpy as cp

n = 100000

I = range(n)
J = range(n);
V = [1]*n

A = spmatrix(V, I, J,(n,n))
x = cp.Variable(n)

tmp = A*x
